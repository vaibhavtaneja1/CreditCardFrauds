# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.getcwd()
# Out:
# 'e:\\git_projects\\CreditCardFrauds'

# %%
df = pd.read_csv("data\creditcard.csv", sep = ',')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %%
# Let's see how many fraudulent samples are there in the entire dataset

nfraud_count = pd.value_counts(df['Class'])[0]
fraud_count = pd.value_counts(df['Class'])[1]
per_fraud_class = (fraud_count/ (fraud_count + nfraud_count))*100
print("Total fraud classes in entire dataset is",round(per_fraud_class, 3),'%')
# Out:
# Total fraud classes in entire dataset is 0.173 %

# %% [markdown]
# ### Dataset Summary:
# <ul>
# <li> The dataset has a total of 284807 rows with 30 features and 1 target feature </li>
# <li> There are no "Na" values </li>
# <li> Most of the transactions were Non-Fraud (99.83%) and Fraud transactions are 0.17% in the dataframe </li>
# <li> The dataset is highly imbalanced </li>
# <li> The features given in the dataframe from V1 to V28 are principal vectors </li>
# <li> Amount and Time are not principal factors and are in the original form </li>
# </ul>

# %%
df.Amount.describe()
# Out:
# count    284807.000000
# mean         88.349619
# std         250.120109
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.165000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
print('Total transactions where amount is greater than 1000: ',df[df['Amount']>1000]['Amount'].count())
print('Fraud Transaction where amount is greater than 1000: ', df[(df['Amount']>1000) & (df['Class'] == 1)]['Amount'].count())
# Out:
# Total transactions where amount is greater than 1000:  2940
# Fraud Transaction where amount is greater than 1000:  9

# %%
fig, ax = plt.subplots(2, 2, figsize=(15,5))

sns.histplot(df[df['Amount']<=500]['Amount'].values, ax=ax[0][0], color='g')
ax[0][0].set_title('Distribution of Transaction Amount', fontsize=14)
ax[0][0].set_xlim([min(df['Amount'].values), 500])
ax[0][0].set_xlabel('Amount')

sns.histplot(df[(df['Amount']>500) & (df['Amount']<=1000)]['Amount'].values, ax=ax[0][1], color='g')
ax[0][1].set_title('Distribution of Transaction Amount', fontsize=14)
ax[0][1].set_xlim([500, 1000])
ax[0][1].set_xlabel('Amount')

sns.histplot(df[(df['Amount']>1000) & (df['Amount']<=2000)]['Amount'].values, ax=ax[1][0], color='g')
ax[1][0].set_xlim([1000, 2000])
ax[1][0].set_xlabel('Amount')

sns.histplot(df[df['Amount']>2000]['Amount'].values, ax=ax[1][1], color='g')
ax[1][1].set_xlim([2000, max(df['Amount'].values)])
ax[1][1].set_xlabel('Amount')

plt.show()

# %% [markdown]
# Clearly, transactions for smaller amount have much higher count as compared to transactions with higher amount. It would be interesting to see the distribution of amount for fraudulent transactions

# %%
# Exploring the time column a bit more
df['Time']
# Out:
# 0              0.0
# 1              0.0
# 2              1.0
# 3              1.0
# 4              2.0
#             ...
# 284802    172786.0
# 284803    172787.0
# 284804    172788.0
# 284805    172788.0
# 284806    172792.0
# Name: Time, Length: 284807, dtype: float64

# %% [markdown]
# The Time column, seems to have second-wise transactions starting from 0 to 172792 secs which translates to 172792/(3600) = 48 hrs. It's safe to assume that we have 48 hrs of credit card transaction data

# %%
fig, ax = plt.subplots(1, 1, figsize=(15,5))

# Plot the distribution of 'Time' feature 
sns.histplot(df['Time'].values/(60*60), ax=ax, color='y')
ax.set_title('Distribution of Transaction Time', fontsize=14)
ax.set_xlim([min(df['Time'].values/(60*60)), max(df['Time'].values/(60*60))])
ax.set_xlabel('Hours')

plt.show()

# %% [markdown]
# ### Summary:
# <ul>
#     <li>Amount: There are mostly small amount transactions in the database</li>
#     <li>Amount: Mean comes out to be 88 dollars and 75th percentile is at 77 dollars</li>
#     <li>Time: as it is evident from the distribution that most of the transactions are occuring during the daytime
# </ul>

# %% [markdown]
# ### Let's look at the distribution of fraudulent transactions now

# %%
fig, ax = plt.subplots(2, 1, figsize=(15,10))

fraud_df = df[df['Class']==1]
# Plot the distribution of 'Time' feature 
sns.histplot(fraud_df['Time'].values/(60*60), ax=ax[0], color='y')
ax[0].set_title('Distribution of Fraudulent Transaction Time', fontsize=14)
ax[0].set_xlim([min(df['Time'].values/(60*60)), max(df['Time'].values/(60*60))])

sns.histplot(fraud_df['Amount'].values, ax=ax[1], color='g')
ax[1].set_title('Distribution of Fraudulent Transaction Amount', fontsize=14)
ax[1].set_xlim([min(fraud_df['Amount'].values), max(fraud_df['Amount'].values)])

plt.show()

# %% [markdown]
# ### Summary:
# <ul>
#     <li>Amount: There are higher fraud cases for smaller amounts</li>
#     <li>The chances of occurence of fraud during night time is greater as compared to day time.</li>
# </ul>

# %%
Nofraud_df = df[df['Class'] == 0]

# %%
fraud_df.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
bins = np.linspace(100, 2125, 200)
plt.figure(figsize = (15,5))
plt.hist(Nofraud_df.Amount,bins, alpha=1, density = True,label='Non-Fraud')
plt.hist(fraud_df.Amount,bins, alpha=0.6, density = True,label='Fraud')
plt.title("Distribution of fraudulent and non-fraudulent transaction w.r.t Amount")
plt.legend()
plt.show()

# %%
bins = np.linspace(0, 48, 48) #48 hours
plt.figure(figsize = (15,5))
plt.hist((Nofraud_df.Time/(60*60)), bins, alpha=1, density=True, label='Non-Fraud')
plt.hist((fraud_df.Time/(60*60)), bins, alpha=0.6, density=True, label='Fraud')
plt.title("Distribution of fraudulent and non-fraudulent transaction w.r.t Time from the first transaction")
plt.legend()
plt.show()

# %%
# Let's see if we can separate fraud and non-fraud transactions by just 2 features i.e. Amount and Time at which it occured

fig = plt.figure(figsize = (15,5))
ax = fig.add_subplot(111)
ax.scatter((Nofraud_df.Time/(60*60)), Nofraud_df.Amount, alpha=0.6, label='Non-Fraud')
ax.scatter((fraud_df.Time/(60*60)), fraud_df.Amount, alpha=0.9, label='Fraud')
ax.set_title("Transaction V/S Hour")
ax.set_xlabel("Transaction time as measured from first transaction in the dataset (hours)")
ax.set_ylabel('Amount $')
ax.legend()
plt.show()

# %% [markdown]
# ### Hence, it is difficult to clearly draw a line which can separate fraud and non-fraud transactions

# %% [markdown]
# #### As we already know that, V1 to V28 are principal components and before converting features into principal componenets, scaling is done. Therefore, we are required to do scale "Amount" and "Time", before proceeding further for model building

# %%
from sklearn.preprocessing import StandardScaler

df['Amount_Scaled'] = StandardScaler().fit_transform(df['Amount'].values.reshape(-1,1))
df['Time_Scaled'] = StandardScaler().fit_transform(df['Time'].values.reshape(-1,1))

# %%
df_new = df.drop(['Time','Amount'], axis = 1)
df_new.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V22       V23       V24       V25  \
# 0  0.098698  0.363787  0.090794  ...  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425 -0.166974  ... -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  0.207643  ...  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024 -0.054952  ...  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  0.753074  ...  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Class  Amount_Scaled  Time_Scaled
# ...

# %%
corr = df_new.corr()
fig = plt.figure(figsize = (24,20))
sns.heatmap(corr, cmap = 'coolwarm', annot=False)

# as expected, since these are Principal Vectors, they will not be correlaed
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Resampling to get rid of imbalanced data

# %% [markdown]
# We can either do **undersampling** of data or **oversampling** of data. What happens in both of them is described below
#
# <ul>
#     <li><b>UnderSampling:</b> we take ramdom draws from non-fraud observations to match the number of fraud observations. But we randomly loose alot of information in this</li>
#     <li><b>OverSampling:</b> Random oversampling duplicates examples from the minority class in the training dataset and can result in overfitting for some models</li>
# </ul>
#
# Apart from these two, we have another method, which is proved more effective as compared to other two mentioned.
# <ul>
# <b>(SMOTE) Synthetic Minority Oversampling Technique:</b> It overcomes the data imbalance by oversampling the minority class (fraud cases) using nearest neighbors of fraud cases to create new synthetic fraud cases instead of duplicating the monority samples </ul>

# %%
x = df_new.drop(['Class'], axis = 1).values
y = df_new.loc[:,['Class']].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.metrics import roc_curve,roc_auc_score, precision_recall_curve, average_precision_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
import warnings
warnings.filterwarnings('ignore')

model = LogisticRegression()
model.fit(x_train, y_train)

# Obtain model predictions
y_pred = model.predict(x_test)
probs = model.predict_proba(x_test)

# %%
fpr, tpr, threshold = roc_curve(y_test, y_pred)

# Calculate AUC
aucScore = roc_auc_score(y_test, probs[:, 1])
 
precision, recall, thresholds = precision_recall_curve(y_test, y_pred)

average_precision = average_precision_score(y_test, y_pred)

# %%
def build_roc_curve(fpr,tpr,aucScore):
    fig = plt.figure(figsize = (15,5))
    ax = fig.add_subplot(111)
    ax.plot(fpr, tpr, label='AUC = %0.3f'% aucScore)
    ax.plot([0,1],[0,1])
    ax.set_title('Receiver operating characteristic curve (ROC)')
    ax.legend()
    ax.set_ylabel('True Positive Rate')
    ax.set_xlabel('False Positive Rate')
    plt.show()

# Define a precision_recall_curve function
def plot_pr_curve(recall, precision, average_precision):
    plt.step(recall, precision, color='b', alpha=0.2, where='post')
    plt.fill_between(recall, precision, step='post', alpha=0.2, color='b')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.ylim([0.0, 1.05])
    plt.xlim([0.0, 1.0])
    plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(average_precision))
    plt.show()

# %%
print('Classification report:\n', classification_report(y_test, y_pred))
print('Confusion matrix:\n',confusion_matrix(y_true = y_test, y_pred = y_pred))

# Plot the roc curve 
build_roc_curve(fpr,tpr,aucScore)

# Plot recall precision curve
plot_pr_curve(recall, precision, average_precision)

prn, rcl = precision[1], recall[1]
print('Recall:', rcl)
print('Precision:', prn)
print('F-Score:', (2*prn*rcl)/(prn+rcl))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85296
#            1       0.88      0.62      0.73       147
#
#     accuracy                           1.00     85443
#    macro avg       0.94      0.81      0.86     85443
# weighted avg       1.00      1.00      1.00     85443
#
# Confusion matrix:
#  [[85284    12]
#  [   56    91]]
# Recall: 0.6190476190476191
# Precision: 0.883495145631068
# F-Score: 0.728

# %% [markdown]
# ___________________________________________________________________________________________________________________
# Terms:
# <ol>
#     <li><b>True Positives:</b> Correctly Classified Fraud Transactions </li>
#     <li><b>False Positives:</b> Transactions which are not fraud but classified as fraud</li>
#     <li><b>True Negative:</b> Correctly Classified Non-Fraud Transactions</li>
#     <li><b>False Negative:</b> Transactions which are fraud but classified as not fraud</li>
#     <li><b>Precision (1-Specificty):</b> TP/(TP + FP) i.e ratio of correct predicted positive to the total predicted positive </li>
#     <li><b>Recall or Sensitivity:</b> TP/(TP + FN) i.e what percentage of fraud is correctly identified</li>
#     <li><b>F1 Score</b> = 2(Recall. Precision) / (Recall + Precision) is the weighted average of Precision and Recall</li>
# </ol>
#
# **Precision** as the name suggests, tells us how precise (how sure) is our model in detecting fraud transactions
# **Recall** is the amount of fraud cases our model is able to detect.
#
# **Precision/Recall Tradeoff:** The more precise (selective) our model is, the less cases it will detect.
# Example: Assuming that our model has a precision of 95%, Let's say there are only 5 fraud cases in which the model is 95% precise or more that these are fraud cases. Then let's say there are 5 more cases that our model considers 90% to be a fraud case, if we lower the precision there are more cases that our model will be able to detect.
# ___________________________________________________________________________________________________________________

# %%
sampling_dict = {'UnderSamp': RandomUnderSampler(random_state=0)
                ,'OverSamp' : RandomOverSampler(random_state=0)
                ,'SMOT': SMOTE(random_state=0)
                }

# %%
for s in sampling_dict.keys():
    sample = sampling_dict[s]
    x_train_smpl, y_train_smpl = sample.fit_sample(x_train, y_train)
    model = LogisticRegression()
    model.fit(x_train_smpl, y_train_smpl)

    y_pred = model.predict(x_test)
    probs = model.predict_proba(x_test)

    aucScore = roc_auc_score(y_test, probs[:, 1])
 
    precision, recall, thresholds = precision_recall_curve(y_test, y_pred)
    
    prn, rcl = precision[1], recall[1]
    print('Recall for',s,'is:', rcl)
    print('Precision for',s,'is:',prn)
    print('F-Score for',s,'is:', (2*prn*rcl)/(prn+rcl))
    print('_'*50)
    x_train_smpl, y_train_smpl = 0,0
# Out:
# Recall for UnderSamp is: 0.9387755102040817
# Precision for UnderSamp is: 0.04129263913824058
# F-Score for UnderSamp is: 0.07910576096302667
# __________________________________________________
# Recall for OverSamp is: 0.9183673469387755
# Precision for OverSamp is: 0.06556580864497329
# F-Score for OverSamp is: 0.12239347234814142
# __________________________________________________
# Recall for SMOT is: 0.9183673469387755
# Precision for SMOT is: 0.06059245960502693
# F-Score for SMOT is: 0.11368421052631579
# __________________________________________________

# %% [markdown]
# ### It is important here that, not in all cases resampling can help us with achieving high precision and high recall

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
y_pred = model.predict(x_test)

precision, recall, th = precision_recall_curve(y_test, y_pred)

print('Classification report:\n', classification_report(y_test, y_pred))
print('Confusion matrix:\n',confusion_matrix(y_true = y_test, y_pred = y_pred))

prn, rcl = precision[1], recall[1]
print('Recall:', rcl)
print('Precision:', prn)
print('F-Score:', (2*prn*rcl)/(prn+rcl))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85296
#            1       0.81      0.76      0.78       147
#
#     accuracy                           1.00     85443
#    macro avg       0.90      0.88      0.89     85443
# weighted avg       1.00      1.00      1.00     85443
#
# Confusion matrix:
#  [[85270    26]
#  [   36   111]]
# Recall: 0.7551020408163265
# Precision: 0.8102189781021898
# F-Score: 0.7816901408450704

# %%
fpr, tpr, threshold = roc_curve(y_test, y_pred)

# Calculate AUC
aucScore = roc_auc_score(y_test, probs[:, 1])
 
precision, recall, thresholds = precision_recall_curve(y_test, y_pred)

average_precision = average_precision_score(y_test, y_pred)

# Plot the roc curve 
build_roc_curve(fpr,tpr,aucScore)

# Plot recall precision curve
plot_pr_curve(recall, precision, average_precision)

# %%
for s in sampling_dict.keys():
    sample = sampling_dict[s]
    x_train_smpl, y_train_smpl = sample.fit_sample(x_train, y_train)
    model = DecisionTreeClassifier()
    model.fit(x_train_smpl, y_train_smpl)

    y_pred = model.predict(x_test)
    probs = model.predict_proba(x_test)

    aucScore = roc_auc_score(y_test, probs[:, 1])
 
    precision, recall, thresholds = precision_recall_curve(y_test, y_pred)
    
    prn, rcl = precision[1], recall[1]
    print('Recall for',s,'is:', rcl)
    print('Precision for',s,'is:',prn)
    print('F-Score for',s,'is:', (2*prn*rcl)/(prn+rcl))
    print('_'*50)
    x_train_smpl, y_train_smpl = 0,0
# Out:
# Recall for UnderSamp is: 0.9047619047619048
# Precision for UnderSamp is: 0.017241379310344827
# F-Score for UnderSamp is: 0.03383793410507569
# __________________________________________________
# Recall for OverSamp is: 0.7006802721088435
# Precision for OverSamp is: 0.7803030303030303
# F-Score for OverSamp is: 0.7383512544802867
# __________________________________________________
# Recall for SMOT is: 0.7755102040816326
# Precision for SMOT is: 0.3787375415282392
# F-Score for SMOT is: 0.5089285714285714
# __________________________________________________

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
import warnings
model = RandomForestClassifier()
model.fit(x_train, y_train)

warnings.filterwarnings('ignore')

# %%
y_pred = model.predict(x_test)

precision, recall, th = precision_recall_curve(y_test, y_pred)

print('Classification report:\n', classification_report(y_test, y_pred))
print('Confusion matrix:\n',confusion_matrix(y_true = y_test, y_pred = y_pred))

prn, rcl = precision[1], recall[1]
print('Recall:', rcl)
print('Precision:', prn)
print('F-Score:', (2*prn*rcl)/(prn+rcl))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85296
#            1       0.95      0.77      0.85       147
#
#     accuracy                           1.00     85443
#    macro avg       0.97      0.88      0.92     85443
# weighted avg       1.00      1.00      1.00     85443
#
# Confusion matrix:
#  [[85290     6]
#  [   34   113]]
# Recall: 0.7687074829931972
# Precision: 0.9495798319327731
# F-Score: 0.849624060150376

# %%
fpr, tpr, threshold = roc_curve(y_test, y_pred)

# Calculate AUC
aucScore = roc_auc_score(y_test, probs[:, 1])
 
precision, recall, thresholds = precision_recall_curve(y_test, y_pred)

average_precision = average_precision_score(y_test, y_pred)

# Plot the roc curve 
build_roc_curve(fpr,tpr,aucScore)

# Plot recall precision curve
plot_pr_curve(recall, precision, average_precision)

# %% [markdown]
# # Support Vector Classifier

# %%
from sklearn.svm import SVC

# %%
model = SVC()
model.fit(x_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
y_pred = model.predict(x_test)

precision, recall, th = precision_recall_curve(y_test, y_pred)

print('Classification report:\n', classification_report(y_test, y_pred))
print('Confusion matrix:\n',confusion_matrix(y_true = y_test, y_pred = y_pred))

prn, rcl = precision[1], recall[1]
print('Recall:', rcl)
print('Precision:', prn)
print('F-Score:', (2*prn*rcl)/(prn+rcl))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85296
#            1       0.94      0.67      0.78       147
#
#     accuracy                           1.00     85443
#    macro avg       0.97      0.83      0.89     85443
# weighted avg       1.00      1.00      1.00     85443
#
# Confusion matrix:
#  [[85290     6]
#  [   49    98]]
# Recall: 0.6666666666666666
# Precision: 0.9423076923076923
# F-Score: 0.7808764940239044

# %%
fpr, tpr, threshold = roc_curve(y_test, y_pred)

# Calculate AUC
aucScore = roc_auc_score(y_test, probs[:, 1])
 
precision, recall, thresholds = precision_recall_curve(y_test, y_pred)

average_precision = average_precision_score(y_test, y_pred)

# Plot the roc curve 
build_roc_curve(fpr,tpr,aucScore)

# Plot recall precision curve
plot_pr_curve(recall, precision, average_precision)
